# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C://Users//win-10//Downloads//wdbc.data")

# %%
df.head()
# Out:
#      842302  M  17.99  10.38   122.8    1001   0.1184   0.2776  0.3001  \
# 0    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 1  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 2  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 3  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
# 4    843786  M  12.45  15.70   82.57   477.1  0.12780  0.17000  0.1578
#
#     0.1471  0.2419  0.07871   1.095  0.9053  8.589  153.4  0.006399  0.04904  \
# 0  0.07017  0.1812  0.05667  0.5435  0.7339  3.398  74.08  0.005225  0.01308
# 1  0.12790  0.2069  0.05999  0.7456  0.7869  4.585  94.03  0.006150  0.04006
# 2  0.10520  0.2597  0.09744  0.4956  1.1560  3.445  27.23  0.009110  0.07458
# 3  0.10430  0.1809  0.05883  0.7572  0.7813  5.438  94.44  0.011490  0.02461
# 4  0.08089  0.2087  0.07613  0.3345  0.8902  2.217  27.19  0.007510  0.03345
#
# ...

# %%
df.shape
# Out:
# (568, 32)

# %%
col_names=['Id', 'Diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean', 
             'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean','fractal dimension_mean','radius_se', 'texture_se', 'perimeter_se', 
             'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se','fractal dimension_se','radius_worst', 'texture_worst', 'perimeter_worst', 
             'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst','fractal dimension_worst']

df.columns=col_names

df.columns
# Out:
# Index(['Id', 'Diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal dimension_worst'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Id                         0
# Diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal dimension_worst    0
# ...

# %%
df
# Out:
#            Id Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842517         M        20.57         17.77          132.90     1326.0
# 1    84300903         M        19.69         21.25          130.00     1203.0
# 2    84348301         M        11.42         20.38           77.58      386.1
# 3    84358402         M        20.29         14.34          135.10     1297.0
# 4      843786         M        12.45         15.70           82.57      477.1
# ..        ...       ...          ...           ...             ...        ...
# 563    926424         M        21.56         22.39          142.00     1479.0
# 564    926682         M        20.13         28.25          131.20     1261.0
# 565    926954         M        16.60         28.08          108.30      858.1
# 566    927241         M        20.60         29.33          140.10     1265.0
# 567     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.columns
# Out:
# Index(['Id', 'Diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal dimension_worst'],
#       dtype='object')

# %%
df_m=df[df['Diagnosis']=='M']

# %%
df_b=df[df['Diagnosis']=='B']

# %%
df_m
# Out:
#            Id Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842517         M        20.57         17.77          132.90     1326.0
# 1    84300903         M        19.69         21.25          130.00     1203.0
# 2    84348301         M        11.42         20.38           77.58      386.1
# 3    84358402         M        20.29         14.34          135.10     1297.0
# 4      843786         M        12.45         15.70           82.57      477.1
# ..        ...       ...          ...           ...             ...        ...
# 562    926125         M        20.92         25.09          143.00     1347.0
# 563    926424         M        21.56         22.39          142.00     1479.0
# 564    926682         M        20.13         28.25          131.20     1261.0
# 565    926954         M        16.60         28.08          108.30      858.1
# 566    927241         M        20.60         29.33          140.10     1265.0
#
# ...

# %%
df_b
# Out:
#            Id Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 18    8510426         B       13.540         14.36           87.46      566.3
# 19    8510653         B       13.080         15.71           85.63      520.0
# 20    8510824         B        9.504         12.44           60.34      273.9
# 36     854941         B       13.030         18.42           82.61      523.8
# 45   85713702         B        8.196         16.84           51.71      201.9
# ..        ...       ...          ...           ...             ...        ...
# 557    925277         B       14.590         22.68           96.39      657.1
# 558    925291         B       11.510         23.93           74.52      403.5
# 559    925292         B       14.050         27.15           91.38      600.4
# 560    925311         B       11.200         29.37           70.67      386.0
# 567     92751         B        7.760         24.54           47.92      181.0
#
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df_m.describe()
# Out:
#                  Id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  2.110000e+02   211.000000    211.000000      211.000000   211.000000
# mean   3.698855e+07    17.460332     21.658104      115.330142   978.269194
# std    1.382021e+08     3.211384      3.708042       21.900590   368.809660
# min    8.670000e+03    10.950000     11.890000       71.900000   361.600000
# 25%    8.619135e+05    15.070000     19.355000       98.710000   705.000000
# 50%    8.956330e+05    17.300000     21.460000      114.200000   930.900000
# 75%    8.911416e+06    19.590000     23.780000      129.950000  1204.500000
# max    9.112962e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       211.000000        211.000000      211.000000           211.000000
# mean          0.102825          0.144560        0.160114             0.087710
# ...

# %%
df_b.describe()
# Out:
#                  Id  radius_mean  texture_mean  perimeter_mean   area_mean  \
# count  3.570000e+02   357.000000    357.000000      357.000000  357.000000
# mean   2.654382e+07    12.146524     17.914762       78.075406  462.790196
# std    1.167397e+08     1.780512      3.995125       11.807438  134.287118
# min    8.913000e+03     6.981000      9.710000       43.790000  143.500000
# 25%    8.746620e+05    11.080000     15.150000       70.870000  378.200000
# 50%    9.089160e+05    12.200000     17.390000       78.180000  458.400000
# 75%    8.812816e+06    13.370000     19.760000       86.100000  551.100000
# max    9.113205e+08    17.850000     33.810000      114.600000  992.100000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       357.000000        357.000000      357.000000           357.000000
# mean          0.092478          0.080085        0.046058             0.025717
# ...

# %%
df_m.describe()
# Out:
#                  Id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  2.110000e+02   211.000000    211.000000      211.000000   211.000000
# mean   3.698855e+07    17.460332     21.658104      115.330142   978.269194
# std    1.382021e+08     3.211384      3.708042       21.900590   368.809660
# min    8.670000e+03    10.950000     11.890000       71.900000   361.600000
# 25%    8.619135e+05    15.070000     19.355000       98.710000   705.000000
# 50%    8.956330e+05    17.300000     21.460000      114.200000   930.900000
# 75%    8.911416e+06    19.590000     23.780000      129.950000  1204.500000
# max    9.112962e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       211.000000        211.000000      211.000000           211.000000
# mean          0.102825          0.144560        0.160114             0.087710
# ...

# %%
df.describe()
# Out:
#                  Id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.680000e+02   568.000000    568.000000      568.000000   568.000000
# mean   3.042382e+07    14.120491     19.305335       91.914754   654.279754
# std    1.251246e+08     3.523416      4.288506       24.285848   351.923751
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692225e+05    11.697500     16.177500       75.135000   420.175000
# 50%    9.061570e+05    13.355000     18.855000       86.210000   548.750000
# 75%    8.825022e+06    15.780000     21.802500      103.875000   782.625000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       568.000000        568.000000      568.000000           568.000000
# mean          0.096321          0.104036        0.088427             0.048746
# ...

# %%
df.head()
# Out:
#          Id Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842517         M        20.57         17.77          132.90     1326.0
# 1  84300903         M        19.69         21.25          130.00     1203.0
# 2  84348301         M        11.42         20.38           77.58      386.1
# 3  84358402         M        20.29         14.34          135.10     1297.0
# 4    843786         M        12.45         15.70           82.57      477.1
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.08474           0.07864          0.0869              0.07017
# 1          0.10960           0.15990          0.1974              0.12790
# 2          0.14250           0.28390          0.2414              0.10520
# 3          0.10030           0.13280          0.1980              0.10430
# 4          0.12780           0.17000          0.1578              0.08089
#
# ...

# %%
col1=df_m['radius_mean']
col2=df_b['radius_mean']

# %%
plt.hist(col1, bins=20, alpha=0.5, label='x')
plt.hist(col2, bins=20, alpha=0.5, label='y')
plt.legend(loc='upper right')
plt.show()

# %%
K_data=df

# %%
K_data
# Out:
#            Id Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842517         M        20.57         17.77          132.90     1326.0
# 1    84300903         M        19.69         21.25          130.00     1203.0
# 2    84348301         M        11.42         20.38           77.58      386.1
# 3    84358402         M        20.29         14.34          135.10     1297.0
# 4      843786         M        12.45         15.70           82.57      477.1
# ..        ...       ...          ...           ...             ...        ...
# 563    926424         M        21.56         22.39          142.00     1479.0
# 564    926682         M        20.13         28.25          131.20     1261.0
# 565    926954         M        16.60         28.08          108.30      858.1
# 566    927241         M        20.60         29.33          140.10     1265.0
# 567     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
K_data.drop('Id', axis=1)
# Out:
#     Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        20.57         17.77          132.90     1326.0
# 1           M        19.69         21.25          130.00     1203.0
# 2           M        11.42         20.38           77.58      386.1
# 3           M        20.29         14.34          135.10     1297.0
# 4           M        12.45         15.70           82.57      477.1
# ..        ...          ...           ...             ...        ...
# 563         M        21.56         22.39          142.00     1479.0
# 564         M        20.13         28.25          131.20     1261.0
# 565         M        16.60         28.08          108.30      858.1
# 566         M        20.60         29.33          140.10     1265.0
# 567         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
K_data
# Out:
#            Id Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842517         M        20.57         17.77          132.90     1326.0
# 1    84300903         M        19.69         21.25          130.00     1203.0
# 2    84348301         M        11.42         20.38           77.58      386.1
# 3    84358402         M        20.29         14.34          135.10     1297.0
# 4      843786         M        12.45         15.70           82.57      477.1
# ..        ...       ...          ...           ...             ...        ...
# 563    926424         M        21.56         22.39          142.00     1479.0
# 564    926682         M        20.13         28.25          131.20     1261.0
# 565    926954         M        16.60         28.08          108.30      858.1
# 566    927241         M        20.60         29.33          140.10     1265.0
# 567     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
N_data=K_data.iloc[:,1:]
N_data
# Out:
#     Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        20.57         17.77          132.90     1326.0
# 1           M        19.69         21.25          130.00     1203.0
# 2           M        11.42         20.38           77.58      386.1
# 3           M        20.29         14.34          135.10     1297.0
# 4           M        12.45         15.70           82.57      477.1
# ..        ...          ...           ...             ...        ...
# 563         M        21.56         22.39          142.00     1479.0
# 564         M        20.13         28.25          131.20     1261.0
# 565         M        16.60         28.08          108.30      858.1
# 566         M        20.60         29.33          140.10     1265.0
# 567         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
#N_data = K_data[data.columns.difference(['Diagnosis'])]
#N_data

# %%
#N_data = N_data.assign(Diagnosis =K_data.iloc[:,1:2])

# %%
N_data
# Out:
#     Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        20.57         17.77          132.90     1326.0
# 1           M        19.69         21.25          130.00     1203.0
# 2           M        11.42         20.38           77.58      386.1
# 3           M        20.29         14.34          135.10     1297.0
# 4           M        12.45         15.70           82.57      477.1
# ..        ...          ...           ...             ...        ...
# 563         M        21.56         22.39          142.00     1479.0
# 564         M        20.13         28.25          131.20     1261.0
# 565         M        16.60         28.08          108.30      858.1
# 566         M        20.60         29.33          140.10     1265.0
# 567         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
#data = N_data.iloc[:,:-1] #all columns except the last one
#target = N_data.iloc[:,30:31] #only the last column

# %%
#data

# %%
#target

# %%
X_train, X_test, y_train, y_test = train_test_split(
    N_data.iloc[:,1:], N_data['Diagnosis'], random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
pred = knn.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,pred))
# Out:
# [[89  3]
#  [ 7 43]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.93      0.97      0.95        92
#            M       0.93      0.86      0.90        50
#
#     accuracy                           0.93       142
#    macro avg       0.93      0.91      0.92       142
# weighted avg       0.93      0.93      0.93       142

# %%
error_rate = []
# Might take some time
for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))
    print(error_rate,i)
# Out:
# [0.07042253521126761] 1
# [0.07042253521126761, 0.07746478873239436] 2
# [0.07042253521126761, 0.07746478873239436, 0.08450704225352113] 3
# [0.07042253521126761, 0.07746478873239436, 0.08450704225352113, 0.07746478873239436] 4
# [0.07042253521126761, 0.07746478873239436, 0.08450704225352113, 0.07746478873239436, 0.07746478873239436] 5
# [0.07042253521126761, 0.07746478873239436, 0.08450704225352113, 0.07746478873239436, 0.07746478873239436, 0.08450704225352113] 6
# [0.07042253521126761, 0.07746478873239436, 0.08450704225352113, 0.07746478873239436, 0.07746478873239436, 0.08450704225352113, 0.07746478873239436] 7
# [0.07042253521126761, 0.07746478873239436, 0.08450704225352113, 0.07746478873239436, 0.07746478873239436, 0.08450704225352113, 0.07746478873239436, 0.07042253521126761] 8
# [0.07042253521126761, 0.07746478873239436, 0.08450704225352113, 0.07746478873239436, 0.07746478873239436, 0.08450704225352113, 0.07746478873239436, 0.07042253521126761, 0.07042253521126761] 9
# ...

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(n_components=1)
lda.fit(X_train, y_train)
#x_test_r2=lda.transform(X_test)
# Out:
# LinearDiscriminantAnalysis(n_components=1)

# %%
lda
X_train_r2 = lda.fit(X_train, y_train).transform(X_train)

# %%
X_train_r2
# Out:
# array([[-9.37673907e-01],
#        [-2.59377766e+00],
#        [-2.00271504e+00],
#        [ 2.77550412e+00],
#        [-9.79908021e-01],
#        [-8.84862111e-01],
#        [ 1.89446933e-01],
#        [-2.56808642e+00],
#        [-6.88420857e-01],
#        [-2.55080534e+00],
#        [-1.63891878e+00],
#        [-1.51058494e+00],
#        [ 9.82013950e-01],
#        [-1.96515555e+00],
#        [-9.43562972e-01],
#        [ 1.54704218e+00],
#        [ 2.07918524e+00],
#        [ 4.39480706e+00],
#        [-1.03437590e+00],
#        [ 3.01483433e+00],
#        [ 2.25282866e+00],
#        [-1.92459524e+00],
#        [ 2.74515420e+00],
#        [-2.47557918e+00],
#        [ 1.74853880e+00],
#        [-6.56095653e-01],
#        [-2.01822770e+00],
#        [-1.65686621e+00],
#        [-2.61075418e+00],
#        [ 1.09537085e+00],
#        [-2.24308707e+00],
#        [ 1.73957894e+00],
#        [-1.40856981e+00],
#        [-1.26633109e+00],
#        [-1.51239929e+00],
# ...

# %%
lda = LinearDiscriminantAnalysis(n_components=1)
X_r2 = lda.fit(X_train, y_train).transform(X_train)

# %%
from sklearn.metrics import accuracy_score
y_pred = lda.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9436619718309859

# %%
l= pd.DataFrame(np.array(X_r2),columns =['ld1'])

# %%
plt.scatter(l,y_train)

# %%
l
# Out:
#           ld1
# 0   -0.937674
# 1   -2.593778
# 2   -2.002715
# 3    2.775504
# 4   -0.979908
# ..        ...
# 421 -1.111297
# 422  0.538646
# 423 -2.087560
# 424  2.046170
# 425 -0.647593
#
# [426 rows x 1 columns]

# %%
y_train
# Out:
# 162    B
# 293    B
# 332    B
# 564    M
# 278    B
#       ..
# 277    B
# 9      M
# 359    B
# 192    M
# 559    B
# Name: Diagnosis, Length: 426, dtype: object

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[89  3]
#  [ 7 43]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.93      0.97      0.95        92
#            M       0.93      0.86      0.90        50
#
#     accuracy                           0.93       142
#    macro avg       0.93      0.91      0.92       142
# weighted avg       0.93      0.93      0.93       142
